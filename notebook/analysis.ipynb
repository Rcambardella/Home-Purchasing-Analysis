# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = os.path.join('..', 'data', 'Analysis_of_homes_since_1984.xlsx')

dataset = pd.read_excel(file_path)

print(dataset.columns)

dataset.drop(['Unnamed: 4', 'Unnamed: 9'], axis=1, inplace=True, errors='ignore')
# Out:
# Index(['Year', 'Annual Change (%)', 'Growth Since 1984 (%)',
#        'Example of $97,600 Home', 'Unnamed: 4', 'YEAR',
#        'AVERAGE MORTGAGE30 RATE', 'AVERAGE MONGTHLY PAYMENT',
#        '% OF PAYMENT COMPARED TO SALARY', 'Unnamed: 9', 'YEAR.1',
#        'MEDIAN HOUSEHOLD INCOME', 'CPI', 'CPI ADJUSTED INCOME',
#        'CHANGE BETWEEN 1984 AND 2024', 'Monthly Income'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.lineplot(data=dataset, x='YEAR', y=dataset['% OF PAYMENT COMPARED TO SALARY'] * 100)
plt.axhline(30, color='red', linestyle='--', label='Affordability Threshold (30%)')
plt.title('Mortgage Cost as % of Income (1984–2024)')
plt.ylabel('Mortgage Burden (%)')
plt.xlabel('Year')
plt.legend()
plt.grid(True)
plt.tight_layout()

chart_path = os.path.join('..', 'charts', 'housing_cost_burden.png')

plt.savefig(chart_path)

plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=dataset, x='Year', y='Example of $97,600 Home', label='Home Price')
sns.lineplot(data=dataset, x='Year', y='MEDIAN HOUSEHOLD INCOME', label='Median Income')
plt.title('Home Prices vs Median Income Over Time')
plt.ylabel('USD ($)')
plt.xlabel('Year')
plt.legend()
plt.grid(True)
plt.tight_layout()

chart_path = os.path.join('..', 'charts', 'home_price_vs_income.png')

plt.savefig(chart_path)

plt.show()
